# %%
import torch
from transformers import AutoModelForSpeechSeq2Seq, AutoProcessor, pipeline
from datasets import load_dataset


device = device = "mps" if torch.backends.mps.is_available() else "cuda:0" if torch.cuda.is_available() else "cpu"
torch_dtype = torch.float16 if torch.cuda.is_available() else torch.float32
# Out:
# /opt/conda/lib/python3.10/site-packages/torchvision/io/image.py:13: UserWarning: Failed to load image Python extension: '/opt/conda/lib/python3.10/site-packages/torchvision/image.so: undefined symbol: _ZN3c1017RegisterOperatorsD1Ev'If you don't plan on using image functionality from `torchvision.io`, you can ignore this warning. Otherwise, there might be something wrong with your environment. Did you have `libjpeg` or `libpng` installed before building `torchvision` from source?
#   warn(
# /opt/conda/lib/python3.10/site-packages/torchvision/datapoints/__init__.py:12: UserWarning: The torchvision.datapoints and torchvision.transforms.v2 namespaces are still Beta. While we do not expect major breaking changes, some APIs may still change according to user feedback. Please submit any feedback you may have in this issue: https://github.com/pytorch/vision/issues/6753, and you can also check out https://github.com/pytorch/vision/issues/7319 to learn more about the APIs that we suspect might involve future changes. You can silence this warning by calling torchvision.disable_beta_transforms_warning().
#   warnings.warn(_BETA_TRANSFORMS_WARNING)
# /opt/conda/lib/python3.10/site-packages/torchvision/transforms/v2/__init__.py:54: UserWarning: The torchvision.datapoints and torchvision.transforms.v2 namespaces are still Beta. While we do not expect major breaking changes, some APIs may still change according to user feedback. Please submit any feedback you may have in this issue: https://github.com/pytorch/vision/issues/6753, and you can also check out https://github.com/pytorch/vision/issues/7319 to learn more about the APIs that we suspect might involve future changes. You can silence this warning by calling torchvision.disable_beta_transforms_warning().
#   warnings.warn(_BETA_TRANSFORMS_WARNING)

# %%
model_id = "openai/whisper-large-v3-turbo"


model = AutoModelForSpeechSeq2Seq.from_pretrained(
    model_id, torch_dtype=torch_dtype, low_cpu_mem_usage=True, use_safetensors=True
)
model.to(device)

processor = AutoProcessor.from_pretrained(model_id)

# %%
import librosa
import numpy as np

def get_video_subtitles(video_path):
    pipe = pipeline(
        "automatic-speech-recognition",
        model=model,
        tokenizer=processor.tokenizer,
        feature_extractor=processor.feature_extractor,
        torch_dtype=torch_dtype,
        device=device,
        return_timestamps=True
    )

    result = pipe(video_path)
    return result["text"]

def get_video_subtitles_and_chunks(video_path):
    audio_data, sr = librosa.load(video_path, sr=16000) 
    # Create input features from audio array
    input_features = processor(
        audio_data, 
        sampling_rate=sr,
        return_tensors="pt", 
        truncation=False
    ).input_features
    
    # Move to appropriate device and convert to correct dtype
    input_features = input_features.to(device, dtype=torch_dtype)
    
    # Generate transcription with timestamps
    generated_ids = model.generate(
        input_features, 
        return_timestamps=True, 
        return_segments=True
    )
    
    # Decode the output with timestamp information
    transcript = processor.batch_decode(
        generated_ids["sequences"], 
        skip_special_tokens=True, 
        output_offsets=True
    )
    
    return transcript
    

# sample = "../../data/test_data/bel.mp4"
sample = "../../data/test_data/long_conversation.mp3"

res = get_video_subtitles_and_chunks(sample)

print(res)
# Out:
# [{'text': " I don't know if you know this, but some people call you a fascist. Yeah, they do. So I figure it's all right to call them a communist. Yeah, they call me a lot worse than I call them. A lot of people listening to this, myself included, that doesn't think that Kamala is a communist. I believe you have to fight fire with fire. Politics is a dirty game. It is a dirty game. It's certainly true. How do you win at that game? They suffer from massive Trump derangement syndrome, TDS, and I don't know if it's curable from their standpoint. I think we'd probably have a better world if everybody in Congress took some mushrooms, perhaps. First of all, medical marijuana has been amazing. I've had friends and I've had others and doctors telling me that it's been absolutely amazing. The list of clients that went to the island has not been made public. Yeah, it's very interesting, isn't it? The following is a conversation with Donald Trump on this, the Lex Friedman podcast. They're getting smaller and smaller. They're getting smaller. Right? I mean, people do respect you more when you have a big camera for some reason. No, it's cool. And about 20 guys that you pay a fortune to, right? All right. Okay. Okay. You said that you love winning and you have won a lot in life, in real estate, in business, in TV, in politics. So let me start with a mindset, a psychology question. What drives you more, the love of winning or the hate of losing? Maybe equally, maybe both. I don't like losing and I do like winning. I've never thought of it as to which is more of a driving force. You've been close with a lot of the greats in sport. You think about Tiger Woods, Muhammad Ali. You have people like Michael Jordan, who I think hate losing more than anybody. So what do you learn from those guys? Well, they do have something different. You know, the great champions have something very different, like the sports champions. And, you know, you have champions in other fields, but you see it more readily in sports. You see it over a weekend or you see it during a game. And you see that certain people stand out and they keep standing out. But it's there for you. It doesn't take a lifetime to find out that somebody was a winner or a loser. And so the sports thing is very interesting. But, you know, I play golf with different people. And you have – there's a different mindset among champions. There's really a very different mindset. There's a different thought process. You know, talent-wise, sometimes you can't tell the difference in talent, but at the end of a weekend, they seem to win. And it's very interesting. Like, as an example, Tiger or Jack Nicklaus, he was a phenomenal winner. And he does have a different way about him. And Tiger has a different way about him. And Michael Jordan. And there's never one, you would think that there'd be one way. Arnold Palmer was the nicest guy you'd ever meet. And then you have some champions that aren't really nice. They're just focused on doing their job. So you have, you know, there's not one type of person. But the one thing I would say that everybody seems to have in common is they're very driven. They're driven like beyond. They don't seem to give up easily. They don't give up, but they do seem to be, you know, they have a passion that's maybe more than people that don't do as well. You've said that politics is a dirty game in the past. Yeah, it is a dirty game. That's certainly true. So if it is a game, how do you win at that game? Well, you win at that game by getting the word out and by using sense. you have to have a feeling where it's going. You also have to have a feeling of what's right. You can't necessarily just go what's popular. You have to do what's good for a country if you're talking about countries. But you have to get the word out. And you have to just continuously, like for instance, you have a great show. You have a great podcast. It's very well watched. And I'm sitting here and I do this. A lo ...

# %%
res[0]["offsets"]
# Out:
# [{'text': " I don't know if you know this, but some people call you a fascist.",
#   'timestamp': (0.0, 3.0)},
#  {'text': ' Yeah, they do.', 'timestamp': (3.2600000000000002, 3.94)},
#  {'text': " So I figure it's all right to call them a communist.",
#   'timestamp': (4.16, 6.42)},
#  {'text': ' Yeah, they call me a lot worse than I call them.',
#   'timestamp': (6.6000000000000005, 8.66)},
#  {'text': " A lot of people listening to this, myself included, that doesn't think that Kamala is a communist.",
#   'timestamp': (8.66, 15.24)},
#  {'text': ' I believe you have to fight fire with fire.',
#   'timestamp': (15.540000000000001, 17.8)},
#  {'text': ' Politics is a dirty game.', 'timestamp': (17.92, 19.32)},
#  {'text': ' It is a dirty game.', 'timestamp': (19.46, 20.56)},
#  {'text': " It's certainly true.", 'timestamp': (20.78, 21.8)},
#  {'text': ' How do you win at that game?', 'timestamp': (21.98, 23.26)},
#  {'text': " They suffer from massive Trump derangement syndrome, TDS, and I don't know if it's curable from their standpoint.",
#   'timestamp': (23.26, 34.84)},
#  {'text': " I think we'd probably have a better world if everybody in Congress took some mushrooms, perhaps.",
#   'timestamp': (35.36, 40.760000000000005)},
#  {'text': ' First of all, medical marijuana has been amazing.',
#   'timestamp': (41.14, 44.980000000000004)},
#  {'text': " I've had friends and I've had others and doctors telling me that it's been absolutely amazing.",
#   'timestamp': (46.08, 52.540000000000006)},
#  {'text': ' The list of clients that went to the island has not been made public.',
#   'timestamp': (52.54, 56.78)},
#  {'text': " Yeah, it's very interesting, isn't it?",
#   'timestamp': (57.76, 60.64)},
#  {'text': ' The following is a conversation with Donald Trump on this, the Lex Friedman podcast.',
#   'timestamp': (62.82, 68.42)},
#  {'text': " They're getting smaller and smaller.",
#   'timestamp': (69.48, 70.82)},
#  {'text': " They're getting smaller.", 'timestamp': (70.86, 71.48)},
#  {'text': ' Right?', 'timestamp': (71.8, 72.08)},
#  {'text': ' I mean, people do respect you more when you have a big camera for some reason.',
#   'timestamp': (72.08, 75.75999999999999)},
#  {'text': " No, it's cool.", 'timestamp': (75.75999999999999, 76.3)},
#  {'text': ' And about 20 guys that you pay a fortune to, right?',
#   'timestamp': (76.4, 78.64)},
#  {'text': ' All right.', 'timestamp': (78.78, 79.2)},
#  {'text': ' Okay.', 'timestamp': (79.92, 80.12)},
#  {'text': ' Okay. You said that you love winning and you have won a lot in life, in real estate,',
#   'timestamp': (80.12, 88.12)},
#  {'text': ' in business, in TV, in politics. So let me start with a mindset, a psychology question.',
#   'timestamp': (88.36, 95.46000000000001)},
#  {'text': ' What drives you more, the love of winning or the hate of losing?',
#   'timestamp': (96.44, 100.42)},
#  {'text': " Maybe equally, maybe both. I don't like losing and I do like winning. I've never thought of it",
#   'timestamp': (100.92, 108.9)},
#  {'text': ' as to which is more of a driving force.',
#   'timestamp': (108.9, 111.4)},
#  {'text': " You've been close with a lot of the greats in sport.",
#   'timestamp': (111.68, 114.64)},
#  {'text': ' You think about Tiger Woods, Muhammad Ali.',
#   'timestamp': (115.54, 118.32000000000001)},
#  {'text': ' You have people like Michael Jordan,',
#   'timestamp': (118.96000000000001, 120.60000000000001)},
#  {'text': ' who I think hate losing more than anybody.',
#   'timestamp': (120.82000000000001, 123.88000000000001)},
#  {'text': ' So what do you learn from those guys?',
#   'timestamp': (124.54, 126.38000000000001)},
#  {'text': ' Well, they do have something different.',
#   'timestamp': (126.72, 128.18)},
#  {'text': ' You know, the great champions have something very different,',
#   'timestamp': (128.48000000000002, 131.44)},
#  {'text': ' like the sports champions.',
#   'timestamp': (131.58, 132.92000000000002)},
#  {'text': ' And, you know, you have champions in other fields,',
#   'timestamp': (132.92000000000002, 135.54000000000002)},
#  {'text': ' but you see it more readily in sports.',
#   'timestamp': (135.72, 137.88)},
#  {'text': ' You see it over a weekend or you see it during a game.',
#   'timestamp': (137.88, 140.26)},
#  {'text': ' And you see that certain people stand out and they keep standing out.',
#   'timestamp': (141.24, 146.5)},
#  {'text': " But it's there for you.", 'timestamp': (147.22, 148.42)},
#  {'text': " It doesn't take a lifetime to find out that somebody was a winner or a loser.",
#   'timestamp': (148.51999999999998, 152.44)},
#  {'text': ' And so the sports thing is very interesting.',
#   'timestamp': (153.7, 155.72)},
#  {'text': ' But, you know, I play golf with different people.',
#   'timestamp': (156.01999999999998, 159.24)},
#  {'text': " And you have – there's a different mindset among champions.",
#   'timestamp': (159.7, 163.88)},
#  {'text': " There's really a very different mindset.",
#   'timestamp': (164.92, 166.3)},
#  {'text': " There's a different thought process.",
#   'timestamp': (166.3, 169.60000000000002)},
#  {'text': " You know, talent-wise, sometimes you can't tell the difference in talent,",
#   'timestamp': (170.3, 173.8)},
#  {'text': ' but at the end of a weekend, they seem to win.',
#   'timestamp': (173.94, 177.12)},
#  {'text': " And it's very interesting.", 'timestamp': (178.06, 179.24)},
#  {'text': ' Like, as an example, Tiger or Jack Nicklaus, he was a phenomenal winner.',
#   'timestamp': (180.12, 185.38000000000002)},
#  {'text': ' And he does have a different way about him.',
#   'timestamp': (185.82000000000002, 187.98000000000002)},
#  {'text': ' And Tiger has a different way about him.',
#   'timestamp': (188.04000000000002, 189.9)},
#  {'text': ' And Michael Jordan.', 'timestamp': (190.08, 191.26000000000002)},
#  {'text': " And there's never one, you would think that there'd be one way.",
#   'timestamp': (191.66000000000003, 194.72000000000003)},
#  {'text': " Arnold Palmer was the nicest guy you'd ever meet.",
#   'timestamp': (194.72, 197.52)},
#  {'text': " And then you have some champions that aren't really nice.",
#   'timestamp': (198.52, 201.08)},
#  {'text': " They're just focused on doing their job.",
#   'timestamp': (201.6, 204.82)},
#  {'text': " So you have, you know, there's not one type of person.",
#   'timestamp': (205.54, 208.8)},
#  {'text': " But the one thing I would say that everybody seems to have in common is they're very driven.",
#   'timestamp': (209.78, 215.96)},
#  {'text': " They're driven like beyond.", 'timestamp': (216.74, 219.16)},
#  {'text': " They don't seem to give up easily.",
#   'timestamp': (219.92, 221.12)},
#  {'text': " They don't give up, but they do seem to be, you know, they have a passion that's maybe more than people that don't do as well.",
#   'timestamp': (221.12, 230.3)},
#  {'text': " You've said that politics is a dirty game in the past.",
#   'timestamp': (231.22, 235.26)},
#  {'text': ' Yeah, it is a dirty game.',
#   'timestamp': (235.52, 236.70000000000002)},
#  {'text': " That's certainly true.",
#   'timestamp': (236.92000000000002, 237.94)},
#  {'text': ' So if it is a game, how do you win at that game?',
#   'timestamp': (238.78, 241.70000000000002)},
#  {'text': ' Well, you win at that game by getting the word out and by using sense.',
#   'timestamp': (241.96, 248.52)},
#  {'text': " you have to have a feeling where it's going. You also have to have a feeling of what's right. You",
#   'timestamp': (248.52, 253.64000000000001)},
#  {'text': " can't necessarily just go what's popular. You have to do what's good for a country if you're",
#   'timestamp': (253.64000000000001, 257.42)},
#  {'text': ' talking about countries. But you have to get the word out. And you have to just continuously,',
#   'timestamp': (257.42, 262.34000000000003)},
#  {'text': " like for instance, you have a great show. You have a great podcast. It's very well watched.",
#   'timestamp': (262.62, 266.98)},
#  {'text': " And I'm sitting here and I do this. A lot of people see it. And I do other things. And a lot",
#   'timestamp': (267.58, 272.58000000000004)},
#  {'text': ' of people see that. And I go traditional also. You have traditional television, which is getting',
#   'timestamp': (272.58000000000004, 278.42)},
#  {'text': " a little bit older and maybe less significant, could be less significant, I don't know.",
#   'timestamp': (278.42, 284.26)},
#  {'text': " But it's changing a lot.",
#   'timestamp': (284.96000000000004, 286.32)},
#  {'text': ' The whole plane of platform is changing a lot.',
#   'timestamp': (286.32, 292.70000000000005)},
#  {'text': " It's changed a lot in the last two, three years.",
#   'timestamp': (292.78000000000003, 295.28000000000003)},
#  {'text': " But from a political standpoint, you have to find out what people are doing, what they're",
#   'timestamp': (296.14, 300.6)},
#  {'text': ' watching, and you have to get on.', 'timestamp': (300.6, 302.76)},
#  {'text': ' I just see that these platforms are starting to dominate.',
#   'timestamp': (303.20000000000005, 307.8)},
#  {'text': " and they're getting very big numbers.",
#   'timestamp': (307.8, 310.52000000000004)},
#  {'text': ' I did spaces with Elon,',
#   'timestamp': (310.52000000000004, 314.28000000000003)},
#  {'text': " and they got numbers like nobody's ever heard before.",
#   'timestamp': (314.28000000000003, 316.78000000000003)},
#  {'text': " So you know, this is, you wouldn't do that on like radio,",
#   'timestamp': (316.78000000000003, 321.62)},
#  {'text': " you wouldn't do that, those numbers,",
#   'timestamp': (321.62, 323.18)},
#  {'text': ' no matter how good a show,', 'timestamp': (323.18, 324.1)},
#  {'text': " you wouldn't do those numbers on radio,",
#   'timestamp': (324.1, 325.54)},
#  {'text': " you wouldn't do them on television.",
#   'timestamp': (325.54, 328.40000000000003)},
#  {'text': " You've been successful in business,",
#   'timestamp': (328.40000000000003, 330.0)},
#  {'text': " you've been successful in politics.",
#   'timestamp': (330.0, 331.48)},
#  {'text': ' What do you think is the difference between gaining success',
#   'timestamp': (331.48, 334.36)},
#  {'text': ' between the two different disparate worlds?',
#   'timestamp': (334.36, 337.32)},
#  {'text': " Yeah, and they're different, very different.",
#   'timestamp': (337.32, 338.96)},
#  {'text': ' I have a lot of people that are in business that are successful,',
#   'timestamp': (340.12, 343.02)},
#  {'text': " and they'd like to go over to politics.",
#   'timestamp': (343.46, 346.02)},
#  {'text': " And then you realize they can't speak.",
#   'timestamp': (346.74, 348.88)},
#  {'text': ' They choke.', 'timestamp': (350.5, 351.3)},
#  {'text': " You know, it's hard to make a speech in front of that.",
#   'timestamp': (352.9, 354.8)},
#  {'text': " Let's say you're talking about a big audience,",
#   'timestamp': (354.9, 356.8)},
#  {'text': ' but I get very big audiences.', 'timestamp': (356.94, 359.2)},
#  {'text': ' And, you know, for many people,', 'timestamp': (359.2, 361.36)},
#  {'text': " it's virtually impossible to get up and speak for an hour and a half.",
#   'timestamp': (361.5, 364.62)},
#  {'text': ' and have nobody leave.', 'timestamp': (364.62, 368.96)},
#  {'text': " It's not an easy thing to do, and it's an ability.",
#   'timestamp': (369.9, 373.2)},
#  {'text': ' But I have many people that are very, very successful in business',
#   'timestamp': (373.86, 378.16)},
#  {'text': " would love to do what I did, and yet they can't pull the trigger.",
#   'timestamp': (378.16, 384.62)},
#  {'text': " And in many cases, I don't think it would work.",
#   'timestamp': (385.56, 387.56)},
#  {'text': " Almost for everybody, it's not going to work.",
#   'timestamp': (387.7, 390.0)},
#  {'text': " It's a very tough thing to do.", 'timestamp': (390.08, 393.22)},
#  {'text': " It's a big transition.",
#   'timestamp': (393.28000000000003, 394.14)},
#  {'text': ' And now, if you talked about people in the business and politics going into business,',
#   'timestamp': (394.62, 400.48)},
#  {'text': " likewise, that wouldn't generally work out so well either.",
#   'timestamp': (401.04, 404.52)},
#  {'text': " It's different talents.", 'timestamp': (404.88, 405.9)},
#  {'text': " It's different skills.", 'timestamp': (406.04, 406.64)},
#  {'text': " I have somebody who wants to go into politics so bad, but he's got a little problem.",
#   'timestamp': (406.78000000000003, 410.68)},
#  {'text': " He's got stage fright.", 'timestamp': (410.78000000000003, 411.8)},
#  {'text': " Now, he's a total killer.", 'timestamp': (412.46, 414.48)},
#  {'text': " But if he gets up into a stage in front of people, he doesn't do well, to put it mildly,",
#   'timestamp': (415.24, 419.98)},
#  {'text': ' actually.', 'timestamp': (420.06, 420.32)},
#  {'text': ' I mean, he does badly.', 'timestamp': (421.1, 422.42)},
#  {'text': ' So you have to be able to make hard decisions like you do in business, but also be able to',
#   'timestamp': (422.42, 428.08000000000004)},
#  {'text': " captivate an audience. Look, if you're a politician, you have to be able to speak in",
#   'timestamp': (428.08000000000004, 432.06)},
#  {'text': " front of large crowds. There are a lot of people who can't do that. I've seen it. They can't even",
#   'timestamp': (432.06, 437.56)},
#  {'text': " think about doing it. And they don't. There are many people in business right now. I could name",
#   'timestamp': (437.56, 443.78000000000003)},
#  {'text': " them, but I don't want to embarrass anybody. They've been talking about running for president",
#   'timestamp': (443.78000000000003, 447.90000000000003)},
#  {'text': " for 15 years. And they're very big in business, very well known, actually. But it takes guts to",
#   'timestamp': (447.90000000000003, 455.56000000000006)},
#  {'text': " run. Like for president, I can tell you it takes guts to run. It's also a very dangerous profession,",
#   'timestamp': (455.56000000000006, 461.50000000000006)},
#  {'text': ' if you want to know the truth, but dangerous in a different sense, too. But it takes a lot of',
#   'timestamp': (461.74, 467.96000000000004)},
#  {'text': " courage to run for president. It's not easy. But you have, and you know the same people as I do,",
#   'timestamp': (467.96000000000004, 473.50000000000006)},
#  {'text': ' There are a lot of people that would like to run for president',
#   'timestamp': (474.42, 477.2)},
#  {'text': ' that are very, very successful in business,',
#   'timestamp': (477.2, 479.54)},
#  {'text': " but they don't have the guts to do it.",
#   'timestamp': (479.92, 482.44)},
#  {'text': ' And they have to give up a lot.', 'timestamp': (482.6, 483.78)},
#  {'text': ' One of the great things about people from the business world',
#   'timestamp': (485.1, 488.24)},
#  {'text': " is they're often great dealmakers.",
#   'timestamp': (488.24, 490.74)},
#  {'text': " And you're a great dealmaker.", 'timestamp': (491.4, 492.68)},
#  {'text': " And you've talked about the war in Ukraine",
#   'timestamp': (493.18, 496.14)},
#  {'text': ' and that you would be able to find a deal',
#   'timestamp': (496.14, 498.52)},
#  {'text': ' that both Putin and Zelensky would accept.',
#   'timestamp': (498.52, 501.46)},
#  {'text': ' What do you think that deal looks like?',
#   'timestamp': (502.20000000000005, 504.12000000000006)},
#  {'text': " I think the deal, and I wouldn't talk about it too much because I think I can make a deal.",
#   'timestamp': (504.90000000000003, 509.54)},
#  {'text': " If I win as president-elect, I'll have a deal made, guaranteed.",
#   'timestamp': (509.78000000000003, 514.0)},
#  {'text': " That's a war that shouldn't have happened.",
#   'timestamp': (514.6800000000001, 516.22)},
#  {'text': " It's terrible.", 'timestamp': (516.34, 517.0400000000001)},
#  {'text': " Look, Biden is the worst president in the history of our country, and she's probably",
#   'timestamp': (517.86, 522.64)},
#  {'text': ' worse than him.', 'timestamp': (522.64, 523.48)},
#  {'text': " That's something that should have never happened, but it did happen.",
#   'timestamp': (524.0, 528.4200000000001)},
#  {'text': " and now it's a much tougher deal to make than it would have been before it started. Millions of",
#   'timestamp': (528.42, 534.4399999999999)},
#  {'text': ' people. I think the number is going to be a lot higher when you see this all at some point iron',
#   'timestamp': (534.4399999999999, 540.04)},
#  {'text': ' out. I think the numbers are going to be, the death numbers are going to be a lot higher than',
#   'timestamp': (540.04, 543.36)},
#  {'text': ' people think. When you take a look at the destruction and the buildings coming down all',
#   'timestamp': (543.36, 548.64)},
#  {'text': ' over the place in Ukraine, I think those numbers are going to be a lot higher. They lie about the',
#   'timestamp': (548.64, 553.54)},
#  {'text': " numbers. They try and keep them low. They knock down a building that's two blocks long. These are",
#   'timestamp': (553.54, 557.88)},
#  {'text': ' big buildings. And they say one person was mildly injured. No, no. A lot of people were killed.',
#   'timestamp': (557.88, 566.24)},
#  {'text': ' And there are people in those buildings and they have no chance. Once they start coming down,',
#   'timestamp': (567.14, 571.4)},
#  {'text': " there's no chance. So that's a war that absolutely has to get done. And then you have",
#   'timestamp': (571.48, 578.1)},
#  {'text': ' Israel and then you have a lot of other places that are talking war. The world is a rough place',
#   'timestamp': (578.1, 584.54)},
#  {'text': " right now. And a lot of it's because of the fact that America has no leadership. And I believe that",
#   'timestamp': (584.54, 591.0999999999999)},
#  {'text': " she'll be probably worse than Biden. I watched the interview the other night. I mean, it was just a",
#   'timestamp': (591.0999999999999, 597.3199999999999)},
#  {'text': " softball interview. So you would like to see her do more interviews, challenged more? I don't know.",
#   'timestamp': (597.3199999999999, 603.4599999999999)},
#  {'text': " I can't believe the whole thing is happening. We had a man in there that should have never been in",
#   'timestamp': (603.56, 608.14)},
#  {'text': ' there. They kept them in a basement. They used COVID. They cheated, but they used COVID to cheat.',
#   'timestamp': (608.14, 613.0799999999999)},
#  {'text': ' that they cheated without COVID too.',
#   'timestamp': (613.08, 614.9200000000001)},
#  {'text': ' But you had somebody in there.', 'timestamp': (615.72, 617.96)},
#  {'text': ' And now we have a woman that is not,',
#   'timestamp': (618.0400000000001, 620.74)},
#  {'text': " I mean, she couldn't do an interview.",
#   'timestamp': (620.9200000000001, 622.4200000000001)},
#  {'text': ' This was a really soft interview.',
#   'timestamp': (622.9200000000001, 624.64)},
#  {'text': " This is an interview where they're given",
#   'timestamp': (624.7800000000001, 626.22)},
#  {'text': ' a multiple choice questions, multiple guests.',
#   'timestamp': (626.22, 630.4200000000001)},
#  {'text': ' I call it multiple guests.', 'timestamp': (630.74, 631.88)},
#  {'text': " And I don't think she did well.",
#   'timestamp': (633.0400000000001, 635.1)},
#  {'text': ' I think she did very poorly.', 'timestamp': (635.2, 636.36)},
#  {'text': " How do you think you'll do in the debate coming up?",
#   'timestamp': (636.8000000000001, 638.72)},
#  {'text': " It's in a few days.", 'timestamp': (638.9000000000001, 639.6)},
#  {'text': " So I've done a lot of debating,", 'timestamp': (639.6, 640.98)},
#  {'text': " only as a politician. I never debated. My first debate was the Rosie O'Donnell debate, right?",
#   'timestamp': (640.98, 646.9)},
#  {'text': " The famous Rosie O'Donnell debate, the answer. But I've done well with debates. I mean, I became",
#   'timestamp': (647.02, 653.1)},
#  {'text': ' president. Then the second time I got millions more votes than I got the first time. So I was',
#   'timestamp': (653.1, 658.36)},
#  {'text': " told if I got 63 million, which is what I got the first time, you would win. You can't not win.",
#   'timestamp': (658.36, 665.3000000000001)},
#  {'text': ' And I got millions of more votes on that and lost by a whisker.',
#   'timestamp': (665.3000000000001, 672.3800000000001)},
#  {'text': ' And look what happened to the world with all of the wars and all of the problems.',
#   'timestamp': (673.44, 677.6800000000001)},
#  {'text': ' And look what happened with inflation because inflation is just eating up our country, eating it up.',
#   'timestamp': (677.6800000000001, 683.82)},
#  {'text': " So it's too bad.",
#   'timestamp': (684.5000000000001, 685.5000000000001)},
#  {'text': ' But there are a lot of things that could happen.',
#   'timestamp': (685.7600000000001, 690.0400000000001)},
#  {'text': ' We have to get those wars settled.',
#   'timestamp': (690.1400000000001, 691.3800000000001)},
#  {'text': " We have to get – I'll tell you, you have to get Ukraine done.",
#   'timestamp': (691.5400000000001, 694.2)},
#  {'text': ' And that could end up in a third world war.',
#   'timestamp': (694.2, 696.2)},
#  {'text': ' So could the Middle East.',
#   'timestamp': (696.2800000000001, 697.22)},
#  {'text': ' So could the Middle East.', 'timestamp': (697.84, 699.0)},
#  {'text': " So maybe let's talk about what it takes to negotiate with somebody like Putin or Zelensky.",
#   'timestamp': (699.5200000000001, 704.82)},
#  {'text': " Do you think Putin would be willing to give up any of the regions they're already captured?",
#   'timestamp': (705.5200000000001, 708.96)},
#  {'text': " I don't know.", 'timestamp': (709.3000000000001, 709.98)},
#  {'text': ' I can tell you that all of this would have never happened.',
#   'timestamp': (710.7800000000001, 715.1)},
#  {'text': " And it would have been very easy because you don't have like that question wouldn't be asked.",
#   'timestamp': (715.1, 719.62)},
#  {'text': " You know, that's a tougher question.",
#   'timestamp': (719.74, 720.96)},
#  {'text': ' Once that starts happening, because he has taken over a lot of territory.',
#   'timestamp': (720.96, 725.26)},
#  {'text': " Now, I guess they're insurgents now too, right?",
#   'timestamp': (725.4000000000001, 728.5600000000001)},
#  {'text': " So it's a little bit interesting that that's happening and that it can happen.",
#   'timestamp': (728.76, 735.0600000000001)},
#  {'text': " And it's interesting that Putin has allowed that to happen.",
#   'timestamp': (735.82, 740.5600000000001)},
#  {'text': " Look, that's one that should have never started.",
#   'timestamp': (741.1800000000001, 744.5400000000001)},
#  {'text': ' We have to get it stopped.',
#   'timestamp': (744.6800000000001, 745.9000000000001)},
#  {'text': ' Ukraine is being demolished.', 'timestamp': (746.24, 748.7)},
#  {'text': " They're destroying a great culture that's largely destroyed.",
#   'timestamp': (748.7, 752.32)},
#  {'text': ' What do you think works better in those kinds of negotiations?',
#   'timestamp': (752.6800000000001, 754.72)},
#  {'text': " Leverage of, let's say, friendship, the carrot or the stick?",
#   'timestamp': (755.76, 759.62)},
#  {'text': ' Friendship or sort of the threat of using the economic and military power?',
#   'timestamp': (759.96, 765.98)},
#  {'text': ' So it depends on who the person is.',
#   'timestamp': (766.08, 767.84)},
#  {'text': " You know, everyone's different.",
#   'timestamp': (768.4000000000001, 769.6400000000001)},
#  {'text': " Negotiation's interesting because it depends on who the person is.",
#   'timestamp': (770.9200000000001, 773.9200000000001)},
#  {'text': ' And then you have to guess or know through certain knowledge which is more important, the carrot or the stick.',
#   'timestamp': (773.9200000000001, 782.2)},
#  {'text': " And with some people, it's the stick, and with some people, it's the carrot.",
#   'timestamp': (783.2, 786.7800000000001)},
#  {'text': " I think the stick probably is generally more successful in that we're talking about war.",
#   'timestamp': (787.3600000000001, 793.82)},
#  {'text': " But the kind of destruction that we're witnessing now, nobody's ever seen.",
#   'timestamp': (794.96, 800.98)},
#  {'text': " I mean, it's a terrible thing.",
#   'timestamp': (801.08, 802.6600000000001)},
#  {'text': " And we're witnessing it all over.", 'timestamp': (802.66, 804.9)},
#  {'text': " We're witnessing it in all parts of the world.",
#   'timestamp': (804.98, 809.4599999999999)},
#  {'text': ' And a lot of things are going to get started.',
#   'timestamp': (809.62, 811.4399999999999)},
#  {'text': " Look what's going on with China.",
#   'timestamp': (811.54, 812.8199999999999)},
#  {'text': ' Look at Japan.', 'timestamp': (813.9, 814.6999999999999)},
#  {'text': " They're starting to rearm now.",
#   'timestamp': (814.8199999999999, 816.2199999999999)},
#  {'text': " They're starting to rearm because China's getting, you know, taking over certain islands.",
#   'timestamp': (816.3399999999999, 820.3)},
#  {'text': " And there's a lot of danger in the war right now in the world.",
#   'timestamp': (820.66, 824.64)},
#  {'text': " There's a lot of, and there's a great possibility of World War III.",
#   'timestamp': (824.86, 829.04)},
#  {'text': ' and we better get this thing done fast because five months with people like her and him,',
#   'timestamp': (829.04, 837.8199999999999)},
#  {'text': " he's checked out.", 'timestamp': (837.88, 838.64)},
#  {'text': " He just goes to the beach and thinks he looks good in a bathing suit, which he doesn't.",
#   'timestamp': (838.7199999999999, 843.12)},
#  {'text': ' He sort of checked out.', 'timestamp': (843.88, 845.26)},
#  {'text': " Hey, look, you know, you can't blame him.",
#   'timestamp': (845.56, 846.9599999999999)},
#  {'text': ' That was a coup.', 'timestamp': (847.74, 848.5)},
#  {'text': ' They took it over.', 'timestamp': (848.7199999999999, 849.42)},
#  {'text': ' They took over the presidential deal.',
#   'timestamp': (849.52, 853.92)},
#  {'text': ' The whole presidential thing was taken over in a coup.',
#   'timestamp': (854.48, 857.26)},
#  {'text': ' He had 14 million votes.', 'timestamp': (857.26, 859.68)},
#  {'text': ' She had no votes, not one.', 'timestamp': (859.74, 860.88)},
#  {'text': ' And nobody thought it was going to be her.',
#   'timestamp': (862.1, 863.62)},
#  {'text': ' Nobody wanted it to be her.',
#   'timestamp': (863.7, 864.8199999999999)},
#  {'text': " She was a joke until six weeks ago when they said we're going to have to,",
#   'timestamp': (865.14, 870.58)},
#  {'text': ' politically, they felt they had to pick her.',
#   'timestamp': (870.74, 872.88)},
#  {'text': " And if they didn't pick her, they thought there'd be a problem.",
#   'timestamp': (874.16, 877.6)},
#  {'text': " I don't know if that's right or not.",
#   'timestamp': (878.46, 879.88)},
#  {'text': " I actually don't think it's right, but, you know, they thought it was right.",
#   'timestamp': (879.96, 883.04)},
#  {'text': ' And now immediately the press comes to their aid.',
#   'timestamp': (883.04, 887.42)},
#  {'text': ' If we can go back to China on negotiation, how do we avoid war with China in the 21st century?',
#   'timestamp': (888.14, 895.7199999999999)},
#  {'text': ' Well, there are ways now.',
#   'timestamp': (896.14, 897.2199999999999)},
#  {'text': " Here's the problem.", 'timestamp': (897.3199999999999, 898.12)},
#  {'text': " If I tell you how, and I'd love to do it, but if I give you a plan, like I have a very",
#   'timestamp': (898.64, 905.98)},
#  {'text': ' exacting plan how to stop Ukraine and Russia.',
#   'timestamp': (905.98, 909.0799999999999)},
#  {'text': ' and I have a certain idea, maybe not a plan, but an idea for China, because we do, you know,',
#   'timestamp': (909.08, 916.5400000000001)},
#  {'text': " we're in a lot of trouble. They'll be in a lot of trouble too, but we're in a lot of trouble.",
#   'timestamp': (916.6, 922.6)},
#  {'text': " But I can't give you those plans because if I give you those plans, I'm not going to be able",
#   'timestamp': (923.44, 927.32)},
#  {'text': " to use them. They'll be very unsuccessful. You know, part of it's surprise, right? But",
#   'timestamp': (927.32, 931.72)},
#  {'text': " they won't be able to help us much. So you have a plan of what to say to Putin.",
#   'timestamp': (931.72, 937.22)},
#  {'text': ' Yeah, I know.', 'timestamp': (937.22, 937.98)},
#  {'text': ' When you take office.', 'timestamp': (937.98, 938.5600000000001)},
#  {'text': ' No, I had a very good relationship with him,',
#   'timestamp': (939.28, 941.22)},
#  {'text': ' and I had a good relationship with Zelensky too,',
#   'timestamp': (941.26, 943.74)},
#  {'text': ' but I had a very good relationship with Putin.',
#   'timestamp': (943.86, 946.64)},
#  {'text': ' Tough topic, but important.', 'timestamp': (947.5, 948.98)},
#  {'text': ' You said loss by a whisker.', 'timestamp': (949.38, 950.76)},
#  {'text': " I'm an independent.", 'timestamp': (951.98, 952.96)},
#  {'text': ' I have a lot of friends who are independent,',
#   'timestamp': (953.48, 955.34)},
#  {'text': ' many of whom like your policies,', 'timestamp': (956.1, 958.64)},
#  {'text': " like the fact that you're a dealmaker,",
#   'timestamp': (959.76, 961.6800000000001)},
#  {'text': ' like the fact that you can end wars,',
#   'timestamp': (962.44, 966.08)},
#  {'text': ' but they are troubled by what happened in the 2020 election',
#   'timestamp': (966.08, 972.12)},
#  {'text': ' and statements about widespread fraud',
#   'timestamp': (972.12, 976.44)},
#  {'text': ' and this kind of stuff, fake election scheme.',
#   'timestamp': (976.44, 978.88)},
#  {'text': ' What can you say to those independent voters',
#   'timestamp': (979.36, 982.5400000000001)},
#  {'text': ' to help them decide who to vote for?',
#   'timestamp': (982.5400000000001, 984.6800000000001)},
#  {'text': ' I think the fraud was on the other side.',
#   'timestamp': (984.6800000000001, 986.6800000000001)},
#  {'text': ' I think the election was a fraud', 'timestamp': (986.82, 988.2)},
#  {'text': ' and many people felt it was that',
#   'timestamp': (988.2, 992.1800000000001)},
#  {'text': ' and they wanted answers.',
#   'timestamp': (992.1800000000001, 993.84)},
#  {'text': " and when you can't challenge an election, you have to be able to challenge it. Otherwise,",
#   'timestamp': (993.84, 999.0400000000001)},
#  {'text': " it's going to get worse, not better. And there are lots of ways to solve this problem. Go to",
#   'timestamp': (999.6600000000001, 1005.8000000000001)},
#  {'text': ' paper ballots and do it the easy way. I mean, paper ballots and you have voter ID and you have',
#   'timestamp': (1005.8000000000001, 1012.48)},
#  {'text': ' same-day voting and you have proof of citizenship, which is very important because we have people',
#   'timestamp': (1012.48, 1017.74)},
#  {'text': " voting that are not citizens. They just came in and they're loading up the payrolls. They're",
#   'timestamp': (1017.74, 1024.68)},
#  {'text': " loading up everything. They're putting students in schools. They don't speak a word of English.",
#   'timestamp': (1024.68, 1028.66)},
#  {'text': " And they're taking the seats of people that are citizens of our country. So,",
#   'timestamp': (1029.34, 1035.38)},
#  {'text': ' look, we have the worst border in the history of the world. We have coming into our country',
#   'timestamp': (1036.26, 1044.02)},
#  {'text': " right now, millions and millions of people at levels that nobody's ever seen. I don't believe",
#   'timestamp': (1044.02, 1048.74)},
#  {'text': " any country's ever seen it. And they would use sticks and stones not to make it happen,",
#   'timestamp': (1048.74, 1054.1)},
#  {'text': " not to let it happen. We don't do anything. And we have a person who was the border czar,",
#   'timestamp': (1054.18, 1059.2)},
#  {'text': " who now said she wasn't really the border czar, but she was the border czar, but she was in charge",
#   'timestamp': (1059.8, 1063.98)},
#  {'text': " of the border. And we have her, and she's saying very strongly, oh, I did such a good job. She was",
#   'timestamp': (1063.98, 1072.44)},
#  {'text': " horrible, horrible, the harm she's done. But we have people coming in from other countries all",
#   'timestamp': (1072.44, 1079.54)},
#  {'text': " over the world, not just South America. And they're coming in from prisons and jails.",
#   'timestamp': (1079.54, 1083.7)},
#  {'text': " They're coming in from mental institutions and insane asylums. And they're street criminals,",
#   'timestamp': (1084.16, 1090.52)},
#  {'text': " right off the street they take them. And they're being given to our country, drug dealers,",
#   'timestamp': (1091.3200000000002, 1096.5800000000002)},
#  {'text': " human traffickers. We're destroying our country. This is a sin what's been allowed to take place",
#   'timestamp': (1097.06, 1103.6799999999998)},
#  {'text': " over the last four years. We're destroying our country. And we'll see how that all works out.",
#   'timestamp': (1103.6799999999998, 1110.08)},
#  {'text': " But it's not even believable. And now you see, you saw in Aurora, Colorado,",
#   'timestamp': (1110.08, 1116.4199999999998)},
#  {'text': ' a group of very tough young thugs from Venezuela taking over big areas, including buildings.',
#   'timestamp': (1117.3999999999999, 1126.4399999999998)},
#  {'text': " They're taking over buildings.",
#   'timestamp': (1126.58, 1127.9199999999998)},
#  {'text': " They have their big rifles, but they're taking over buildings.",
#   'timestamp': (1128.02, 1132.12)},
#  {'text': " We're not going to let this happen.",
#   'timestamp': (1132.5, 1134.12)},
#  {'text': " We're not going to let them destroy our country.",
#   'timestamp': (1134.48, 1136.6)},
#  {'text': ' And you know, in those countries, crime is way down.',
#   'timestamp': (1137.12, 1140.0)},
#  {'text': " They're taking them out of their prisons, which is good because it's good for them.",
#   'timestamp': (1140.08, 1143.6599999999999)},
#  {'text': ' I do the same thing.',
#   'timestamp': (1143.8799999999999, 1144.8799999999999)},
#  {'text': ' By the way, if I ran one of those countries, any country in the world, I would make sure',
#   'timestamp': (1145.06, 1148.54)},
#  {'text': ' that America has every one of our prisoners.',
#   'timestamp': (1148.54, 1150.34)},
#  {'text': ' Every one of our criminals would be here.',
#   'timestamp': (1150.86, 1152.6)},
#  {'text': " I can't believe they're going so slowly, but some aren't.",
#   'timestamp': (1152.96, 1156.3799999999999)},
#  {'text': ' But they all are doing it.',
#   'timestamp': (1156.58, 1158.6999999999998)},
#  {'text': " And we can't let that happen.",
#   'timestamp': (1159.46, 1161.1399999999999)},
#  {'text': " They're emptying out their prisons and their mental institutions into the United States of America.",
#   'timestamp': (1161.36, 1168.1)},
#  {'text': " We can't let that happen.", 'timestamp': (1168.28, 1169.3)},
#  {'text': ' So a lot of people believe that there was some shady stuff that went on with the election,',
#   'timestamp': (1169.96, 1174.04)},
#  {'text': " whether it's media bias or big tech.",
#   'timestamp': (1174.46, 1177.08)},
#  {'text': ' But still, the claim of widespread fraud is the thing that bothers people.',
#   'timestamp': (1177.6999999999998, 1182.28)},
#  {'text': " Well, I don't focus on the past.",
#   'timestamp': (1182.28, 1185.36)},
#  {'text': ' I focus on the future. I mean, I talk about how bad the economy is, how bad inflation is,',
#   'timestamp': (1185.3600000000001, 1189.68)},
#  {'text': ' how bad things like, which is important. Afghanistan was, in my opinion, the most',
#   'timestamp': (1190.66, 1197.64)},
#  {'text': " embarrassing thing that's ever happened to our country. And because of that, I think Putin went",
#   'timestamp': (1197.64, 1202.2600000000002)},
#  {'text': ' in. When he said how stupid we were, Putin went in. But it was the most embarrassing moment in',
#   'timestamp': (1202.2600000000002, 1210.5400000000002)},
#  {'text': ' the history of our country. I really believe that. But we left 13 dead soldiers. Think of it,',
#   'timestamp': (1210.54, 1219.58)},
#  {'text': ' 13 dead soldiers. Many soldiers horrifically hurt with arms and legs and everything else gone.',
#   'timestamp': (1219.6399999999999, 1225.26)},
#  {'text': ' We left hostages behind. We left Americans behind. We left military equipment, the likes of which',
#   'timestamp': (1226.84, 1234.36)},
#  {'text': " nobody's ever left behind before. Billions and billions of dollars of equipment. They're now",
#   'timestamp': (1234.3600000000001, 1240.8000000000002)},
#  {'text': " selling the equipment. They're one of the largest arms dealers in the world. And very sad, very sad.",
#   'timestamp': (1240.8000000000002, 1249.4)},
#  {'text': ' And we were there for a long time. I was going to get out. We were getting ready to get out. Then',
#   'timestamp': (1249.4, 1256.22)},
#  {'text': ' we got interrupted by the election. But we would have been out with dignity and strength.',
#   'timestamp': (1256.22, 1260.96)},
#  {'text': ' we were having very little problem with the Taliban when I was there because they knew it',
#   'timestamp': (1260.96, 1266.44)},
#  {'text': ' was going to be tough. I dealt with Abdul. Abdul was the leader. And we got along fine. He understood.',
#   'timestamp': (1266.44, 1274.6000000000001)},
#  {'text': ' But, you know, they were shooting. They were killing a lot of our people before',
#   'timestamp': (1274.98, 1278.16)},
#  {'text': " I came down. And when I got there, I said, I spoke to him. I said, you can't do it. Don't do it",
#   'timestamp': (1278.16, 1284.04)},
#  {'text': ' anymore. We went 18 months before this happened, this horrible day happened. We went 18 months and',
#   'timestamp': (1284.04, 1291.72)},
#  {'text': ' nobody was shot at or killed. What do you think that was, the carrot or the stick in that case',
#   'timestamp': (1291.72, 1296.28)},
#  {'text': ' in Afghanistan? The stick, definitely. So the threat of military force. That was the stick,',
#   'timestamp': (1296.28, 1301.6399999999999)},
#  {'text': " yeah. It doesn't have to be, but that was the stick. Well, let me just linger on the election",
#   'timestamp': (1301.74, 1306.12)},
#  {'text': ' a little bit more. For this election, it might be a close one. What can we do to avoid the insanity',
#   'timestamp': (1306.12, 1313.6399999999999)},
#  {'text': ' and division of the previous election,',
#   'timestamp': (1313.64, 1315.7800000000002)},
#  {'text': ' whether you win or lose?', 'timestamp': (1315.96, 1317.38)},
#  {'text': " Well, I hope it's not a close one.",
#   'timestamp': (1318.0, 1319.5600000000002)},
#  {'text': " I mean, I don't know how people can vote",
#   'timestamp': (1319.74, 1321.5400000000002)},
#  {'text': ' for somebody that has destroyed our country.',
#   'timestamp': (1321.5400000000002, 1324.3000000000002)},
#  {'text': ' The inflation, the bad economy,',
#   'timestamp': (1324.5600000000002, 1326.94)},
#  {'text': ' but to me, in a way, the worst', 'timestamp': (1327.26, 1330.0)},
#  {'text': " is what they've allowed to happen at our border,",
#   'timestamp': (1330.0, 1332.6000000000001)},
#  {'text': " where they've allowed millions of people",
#   'timestamp': (1332.74, 1334.2)},
#  {'text': ' to come and hear from places',
#   'timestamp': (1334.2, 1335.5600000000002)},
#  {'text': " that you don't want to know about.",
#   'timestamp': (1335.5600000000002, 1337.3000000000002)},
#  {'text': " And I can't believe that that's going to be a close election.",
#   'timestamp': (1338.26, 1340.98)},
#  {'text': " You know, we're leading in the polls,",
#   'timestamp': (1341.16, 1342.3600000000001)},
#  {'text': " And it looks close, but I think in the end it's not going to be a close election.",
#   'timestamp': (1343.1200000000001, 1348.5400000000002)},
#  {'text': ' What do you think is the right way to solve the immigration crisis?',
#   'timestamp': (1349.2800000000002, 1351.7400000000002)},
#  {'text': ' Is mass deportation one of the solutions you would think about?',
#   'timestamp': (1352.0800000000002, 1355.42)},
#  {'text': " Well, you've got to get the criminals out of here fast, right?",
#   'timestamp': (1355.5600000000002, 1358.5200000000002)},
#  {'text': " You know, the people from mental institutions, you've got to get them back into their mental institution.",
#   'timestamp': (1358.5200000000002, 1363.7)},
#  {'text': ' No country can afford this.',
#   'timestamp': (1363.98, 1365.3600000000001)},
#  {'text': " You know, it's just too much money.",
#   'timestamp': (1365.44, 1367.2)},
#  {'text': " You look at what's happening in New York and Chicago and L.A. and lots of places, and you take a look at what's happening.",
#   'timestamp': (1367.2, 1374.8400000000001)},
#  {'text': " There's no country can afford this.",
#   'timestamp': (1374.96, 1376.3400000000001)},
#  {'text': " We can't afford it.", 'timestamp': (1376.42, 1377.3)},
#  {'text': " And we've got to get the bad ones out immediately, and the rest have to be worked on.",
#   'timestamp': (1378.26, 1383.68)},
#  {'text': " You know, it's happened before.", 'timestamp': (1384.28, 1385.2)},
#  {'text': ' Dwight Eisenhower was sort of a moderate president, moderate-type person, but he hated when he saw people pouring into the country, and they were.',
#   'timestamp': (1385.28, 1393.8400000000001)},
#  {'text': ' Nothing like now.', 'timestamp': (1394.16, 1395.22)},
#  {'text': ' You know, I probably got elected in 2016 because of the border.',
#   'timestamp': (1395.22, 1399.42)},
#  {'text': ' And I told people what was happening and they understood it.',
#   'timestamp': (1400.74, 1403.58)},
#  {'text': ' And I won the election and I won the election, I think, because of the border.',
#   'timestamp': (1403.78, 1407.64)},
#  {'text': ' Our border is 25 times worse right now than it was in 2016.',
#   'timestamp': (1407.96, 1413.58)},
#  {'text': ' I had it fixed.', 'timestamp': (1415.34, 1416.14)},
#  {'text': ' I had it the last week of my, the famous chart that I put up was exactly that.',
#   'timestamp': (1416.38, 1422.72)},
#  {'text': ' You know the chart.', 'timestamp': (1422.78, 1423.5)},
#  {'text': " But when I looked to the right, I said, there's the chart.",
#   'timestamp': (1423.5, 1426.62)},
#  {'text': ' Bing.', 'timestamp': (1426.8, 1427.0)},
#  {'text': ' That was not a pleasant experience.',
#   'timestamp': (1428.26, 1430.0)},
#  {'text': ' But the chart that I put up said, and that was done by Border Patrol,',
#   'timestamp': (1430.52, 1433.92)},
#  {'text': " that was the lowest number that we've ever had come into our country",
#   'timestamp': (1434.32, 1437.56)},
#  {'text': ' in recorded history.', 'timestamp': (1437.56, 1438.64)},
#  {'text': ' And we have to get it back to that again.',
#   'timestamp': (1439.68, 1442.3)},
#  {'text': ' We will.', 'timestamp': (1442.56, 1443.1)},
#  {'text': ' Let me ask you about Project 2025.',
#   'timestamp': (1443.8, 1445.7)},
#  {'text': " So you've publicly said that you don't have any direct connection to Project 20.",
#   'timestamp': (1446.16, 1449.18)},
#  {'text': ' Nothing.', 'timestamp': (1449.18, 1449.66)},
#  {'text': ' I know nothing about it.', 'timestamp': (1449.94, 1451.3)},
#  {'text': ' And they know that, too.', 'timestamp': (1451.3, 1452.42)},
#  {'text': " Democrats know that. And I purposely haven't read it because I want to say to you, I have no idea",
#   'timestamp': (1452.42, 1458.76)},
#  {'text': " what it's all about. It's easier than saying I read it and all of the things. No, I purposely",
#   'timestamp': (1458.76, 1464.7)},
#  {'text': " haven't read it. And I've heard about it. I've heard about things that are in there that I don't",
#   'timestamp': (1464.7, 1472.28)},
#  {'text': ' like. And there are some things in there that everybody would like. But there are things that',
#   'timestamp': (1472.28, 1476.5600000000002)},
#  {'text': " I don't like at all. And I think it's unfortunate that they put it out, but it doesn't mean anything",
#   'timestamp': (1476.56, 1485.7)},
#  {'text': ' because it has nothing to do with me. Project 25 has absolutely nothing to do with me.',
#   'timestamp': (1485.7, 1491.36)},
#  {'text': " You posted recently about marijuana and that you're okay with it being legalized,",
#   'timestamp': (1492.52, 1500.48)},
#  {'text': ' but it has to be done safely. Can you explain your policy there?',
#   'timestamp': (1500.56, 1502.96)},
#  {'text': " Well, I just put out a paper. And first of all, medical marijuana has been amazing. I've had friends and I've had others and doctors telling me that it's been absolutely amazing, the medical marijuana.",
#   'timestamp': (1502.96, 1519.48)},
#  {'text': ' and we put out a statement that we can live with the marijuana.',
#   'timestamp': (1519.48, 1527.08)},
#  {'text': " It's got to be a certain age.", 'timestamp': (1527.4, 1528.7)},
#  {'text': " It's got to be a certain age to buy it.",
#   'timestamp': (1528.98, 1530.5)},
#  {'text': " It's got to be done in a very concerted, lawful way.",
#   'timestamp': (1531.18, 1535.38)},
#  {'text': " And the way they're doing it in Florida, I think, is going to be actually good.",
#   'timestamp': (1536.74, 1541.06)},
#  {'text': " It's going to be very good.", 'timestamp': (1541.1, 1542.16)},
#  {'text': " But it's got to be done in a good way.",
#   'timestamp': (1542.78, 1544.56)},
#  {'text': " It's got to be done in a clean way.",
#   'timestamp': (1544.6200000000001, 1546.08)},
#  {'text': ' You go into some of these places, like in New York,',
#   'timestamp': (1546.46, 1548.56)},
#  {'text': ' It smells all marijuana.', 'timestamp': (1548.56, 1550.5)},
#  {'text': " You can't, the way, you've got to have a system where there's control.",
#   'timestamp': (1550.76, 1554.1799999999998)},
#  {'text': " And I think the way they've done it in Florida is very good.",
#   'timestamp': (1555.44, 1558.6399999999999)},
#  {'text': ' Do you know anything about psychedelics?',
#   'timestamp': (1559.22, 1560.72)},
#  {'text': " So I'm not a drug guy, but I recently did ayahuasca.",
#   'timestamp': (1561.3, 1564.1)},
#  {'text': ' Yeah.', 'timestamp': (1564.96, 1565.22)},
#  {'text': " And there's a lot of people that speak to sort of the health benefits",
#   'timestamp': (1566.06, 1571.1399999999999)},
#  {'text': ' and the spiritual benefits of these different psychedelics.',
#   'timestamp': (1571.1399999999999, 1575.54)},
#  {'text': ' I think we would probably have a better world if everybody in Congress took some mushrooms, perhaps.',
#   'timestamp': (1575.54, 1581.92)},
#  {'text': ' Now, I know you stay away from all of that stuff.',
#   'timestamp': (1583.32, 1585.6399999999999)},
#  {'text': ' I know also veterans use it for dealing with PTSD and all that kind of stuff.',
#   'timestamp': (1587.58, 1591.86)},
#  {'text': " So it's great, and it's interesting that you're thinking about being more accepting of some of these drugs,",
#   'timestamp': (1592.0, 1599.3)},
#  {'text': " which don't just have a recreational purpose, but a medical purpose, a treatment purpose.",
#   'timestamp': (1599.44, 1604.76)},
#  {'text': " So we put out a statement today. We're going to put out another one probably next week, be more specific, although I think it's pretty specific. And we'll see how that all goes. That's a referendum coming up in some states, but it's coming up and we'll see how it does. I will say it's been very hard to beat it. You take a look at the numbers, it's been very hard to beat it. So I think it'll generally pass, but you want to do it in a safe way.",
#   'timestamp': (1604.76, 1633.52)},
#  {'text': ' Speaking of marijuana, let me ask you about my good friend Joe Rogan.',
#   'timestamp': (1633.52, 1637.52)},
#  {'text': ' So you had a bit of tension with him. So when he said nice things about RFK Jr., I think,',
#   'timestamp': (1637.52, 1643.36)},
#  {'text': " you've said some not so nice things about Joe. I think that was a bit unfair. And as a fan of Joe,",
#   'timestamp': (1644.0, 1650.96)},
#  {'text': ' I would love to see you do his podcast because he is legit the greatest conversationalist in the',
#   'timestamp': (1651.76, 1658.8)},
#  {'text': " world. So what's the story behind the tension? Well, I don't think there was any tension.",
#   'timestamp': (1658.8, 1662.8799999999999)},
#  {'text': " and I've always liked him, but I don't know him.",
#   'timestamp': (1662.88, 1668.5800000000002)},
#  {'text': ' I only see him when I walk into the arena with Dana',
#   'timestamp': (1669.5800000000002, 1672.5)},
#  {'text': ' and I shake his hand.', 'timestamp': (1672.5, 1674.5)},
# ...
#   'timestamp': (3211.7000000000003, 3218.0200000000004)},
#  {'text': ' criminal activity by a small minority of its users, for example, by terrorist groups to',
#   'timestamp': (3218.0200000000004, 3223.7400000000002)},
#  {'text': " communicate. And I think we all agree that terrorism is bad. But here's the problem. As the",
#   'timestamp': (3223.7400000000002, 3229.6000000000004)},
#  {'text': " old saying goes, one man's terrorist is another man's freedom fighter. And there are many cases",
#   'timestamp': (3229.6000000000004, 3235.4)},
#  {'text': ' in which the world unilaterally agrees who the terrorists are. But there are other cases when',
#   'timestamp': (3235.4, 3241.6800000000003)},
#  {'text': ' governments, especially authoritarian inclined governments, tend to propagandize and just call',
#   'timestamp': (3241.6800000000003, 3247.5200000000004)},
#  {'text': " whoever's in the opposition, whoever opposes them, terrorists. There is some room for nuance here.",
#   'timestamp': (3247.5200000000004, 3253.0600000000004)},
#  {'text': ' But to me, at this time, it seems to obviously be a power grab by government wanting to have backdoor access into every platform so they can have censorship power against the opposition.',
#   'timestamp': (3253.06, 3265.54)},
#  {'text': ' I think generally, government should stay out of censoring or even pressuring social media platforms.',
#   'timestamp': (3266.48, 3272.4)},
#  {'text': ' And I think arresting a CEO of a tech company for the things said on the platform he built is just nuts.',
#   'timestamp': (3272.96, 3279.36)},
#  {'text': ' It has a chilling effect on him, on people working at Telegram, and on people working at every social media company.',
#   'timestamp': (3280.2200000000003, 3286.4)},
#  {'text': ' And also people thinking of launching a new social media company.',
#   'timestamp': (3286.8, 3289.84)},
#  {'text': ' Same as the case of X being banned in Brazil.',
#   'timestamp': (3290.44, 3293.4)},
#  {'text': " It's, I think, a power grab by Alexandre de Marais, a Supreme Court justice in Brazil.",
#   'timestamp': (3293.96, 3299.6200000000003)},
#  {'text': ' He ordered X to block certain accounts that are spreading quote-unquote misinformation.',
#   'timestamp': (3299.8, 3304.6)},
#  {'text': ' Elon and X denied the request.', 'timestamp': (3305.6, 3307.88)},
#  {'text': ' Then Demarias threatened to arrest X representatives in Brazil.',
#   'timestamp': (3308.58, 3313.2000000000003)},
#  {'text': ' And in response to that, X pulled the representatives out of Brazil, obviously, to protect them.',
#   'timestamp': (3313.2000000000003, 3319.1800000000003)},
#  {'text': ' And now X having no representatives in Brazil apparently violates the law.',
#   'timestamp': (3319.98, 3324.1)},
#  {'text': ' Based on this, Demarias banned X in Brazil.',
#   'timestamp': (3324.6800000000003, 3328.02)},
#  {'text': " Once again, it's an authoritarian figure seeking censorship power over the channels of communication.",
#   'timestamp': (3328.6800000000003, 3333.6400000000003)},
#  {'text': ' I understand that this is complicated because there are evil people in the world and part of',
#   'timestamp': (3333.64, 3339.92)},
#  {'text': ' the role of government is to protect us from those evil people but as Benjamin Franklin said',
#   'timestamp': (3339.92, 3345.54)},
#  {'text': ' those who can give up essential liberty to obtain a little temporary safety deserve neither liberty',
#   'timestamp': (3345.54, 3350.98)},
#  {'text': " nor safety so it's a trade-off but I think in many places in the world many governments have",
#   'timestamp': (3350.98, 3358.18)},
#  {'text': ' lean too far away at this time from liberty. Okay, next up, I got a question on AI, which I',
#   'timestamp': (3358.1800000000003, 3366.1000000000004)},
#  {'text': " emotionally connected with. I'll condense it as follows. Hello, Lex. I'm a programmer, and I have",
#   'timestamp': (3366.1000000000004, 3374.32)},
#  {'text': ' a deep fear of slipping into irrelevance because I am worried that AI will soon exceed my programming',
#   'timestamp': (3374.32, 3380.32)},
#  {'text': " skills. Let me first say that I relate to your fear. It's scary to have a thing that gives you",
#   'timestamp': (3380.32, 3387.26)},
#  {'text': ' a career and gives you meaning to be taken away. For me, programming is a passion. And if not for',
#   'timestamp': (3387.26, 3394.1600000000003)},
#  {'text': ' this podcast, it would probably, at least in part, be my profession. So I get an uncomfortable feeling',
#   'timestamp': (3394.1600000000003, 3401.2000000000003)},
#  {'text': ' every time Claude, the LLM I use for coding at this time, just writes a lot of excellent,',
#   'timestamp': (3401.2000000000003, 3406.5)},
#  {'text': ' approximately correct code. I think you can make a good case that it already exceeds the skill of',
#   'timestamp': (3407.7200000000003, 3413.5800000000004)},
#  {'text': ' many programmers, at least in the same way that the collective intelligence of stack overflow',
#   'timestamp': (3413.58, 3418.06)},
#  {'text': ' exceeds the skill of many programmers, many individual programmers. But in many ways,',
#   'timestamp': (3418.06, 3423.64)},
#  {'text': ' it still does not. But I think eventually, more and more, the task, the profession of programming',
#   'timestamp': (3423.7, 3431.36)},
#  {'text': " will be one of writing natural language prompts. I think the right thing to do, and what I'm",
#   'timestamp': (3431.36, 3438.24)},
#  {'text': ' at least doing is to ride the wave of the ever-improving code generating LLMs and keep',
#   'timestamp': (3438.2400000000002, 3445.0000000000005)},
#  {'text': " transforming myself into a big picture designer versus low-level tinkerer. What I'm doing and",
#   'timestamp': (3445.0000000000005, 3451.3)},
#  {'text': ' what I recommend you do is continually switch to whatever state-of-the-art tool is for generating',
#   'timestamp': (3451.3, 3456.6600000000003)},
#  {'text': ' code. So for me currently, I recently switched from VS Code to Cursor. And before that, it was',
#   'timestamp': (3456.6600000000003, 3462.6400000000003)},
#  {'text': " emacs to vs code switch so cursor is this editor that's based on vs code that uh leans heavily on",
#   'timestamp': (3462.64, 3470.64)},
#  {'text': ' llms and integrates the code generation really nicely into the editing process so it makes it',
#   'timestamp': (3470.64, 3477.44)},
#  {'text': " super easy to uh continually use the llms so what i would advise and what i'm trying to do myself is",
#   'timestamp': (3477.44, 3484.0)},
#  {'text': ' to learn how to use it and to master its code generation capabilities i personally try to now',
#   'timestamp': (3484.0, 3489.68)},
#  {'text': ' allocate a significant amount of time to designing with natural language first versus writing code',
#   'timestamp': (3489.6800000000003, 3496.38)},
#  {'text': " from scratch. So using my understanding of programming to edit the code that's generated",
#   'timestamp': (3496.38, 3503.9)},
#  {'text': ' by the LLM versus sort of writing it from scratch and then using the LLM to generate small parts of',
#   'timestamp': (3503.9, 3509.92)},
#  {'text': ' the code. I see it as a skill that I should develop in parallel to my programming skill.',
#   'timestamp': (3509.92, 3514.1400000000003)},
#  {'text': " I think this applies to many other careers too. Don't compete with AI for your job.",
#   'timestamp': (3514.7000000000003, 3518.9)},
#  {'text': ' learn to use the AI to do that job better.',
#   'timestamp': (3519.6800000000003, 3522.3)},
#  {'text': ' But yes, it is scary on some deep sort of human level,',
#   'timestamp': (3523.0200000000004, 3528.6000000000004)},
#  {'text': ' the threat of being replaced.',
#   'timestamp': (3529.4, 3530.6400000000003)},
#  {'text': " But at least I think we'll be okay.",
#   'timestamp': (3531.5200000000004, 3534.1200000000003)},
#  {'text': ' All right, next up, I got a very nice audio message',
#   'timestamp': (3535.34, 3538.5200000000004)},
#  {'text': ' and question from a gentleman who is 27',
#   'timestamp': (3538.5200000000004, 3542.4)},
#  {'text': ' and feeling a lot of anxiety about the future.',
#   'timestamp': (3542.4, 3544.6400000000003)},
#  {'text': " Just recently, he graduated with a bachelor's degree",
#   'timestamp': (3545.1800000000003, 3547.5600000000004)},
#  {'text': " and he's thinking about going to grad school",
#   'timestamp': (3547.5600000000004, 3549.42)},
#  {'text': ' for biomedical engineering. But there is a lot of anxiety. He mentioned anxiety many times in the',
#   'timestamp': (3549.42, 3555.52)},
#  {'text': ' message. It took him an extra while to get his degree. So he mentioned he would be 32 by the',
#   'timestamp': (3555.52, 3560.76)},
#  {'text': " time he's done with his PhD. So it's a big investment. But he said in his heart, he feels",
#   'timestamp': (3560.76, 3567.2400000000002)},
#  {'text': " like he's a scientist. I think that's the most important part of his message, of your message.",
#   'timestamp': (3567.2400000000002, 3572.56)},
#  {'text': " By the way, I'll figure out how to best include audio and video messages in future episodes.",
#   'timestamp': (3573.04, 3577.02)},
#  {'text': ' Now, on to the question.', 'timestamp': (3577.66, 3579.16)},
#  {'text': ' So thank you for telling me your story and for submitting the question.',
#   'timestamp': (3579.7, 3583.02)},
#  {'text': ' My own life story is similar to yours.',
#   'timestamp': (3583.62, 3585.1)},
#  {'text': " I went to Drexel University for my bachelor's, master's, and doctorate degrees.",
#   'timestamp': (3585.7, 3590.98)},
#  {'text': " And I took a while, just as you're doing.",
#   'timestamp': (3591.58, 3594.84)},
#  {'text': " I did a lot of nonstandard things that weren't any good for some hypothetical career I'm supposed to have.",
#   'timestamp': (3595.16, 3601.82)},
#  {'text': ' I trained and competed in judo and jiu-jitsu for my entire 20s.',
#   'timestamp': (3602.56, 3606.42)},
#  {'text': ' Got a black belt from it.',
#   'timestamp': (3607.02, 3608.7599999999998)},
#  {'text': ' I wrote a lot, including a lot of really crappy poetry.',
#   'timestamp': (3609.6, 3613.64)},
#  {'text': ' I read a large amount of non-technical books, history, philosophy, and literature.',
#   'timestamp': (3614.48, 3619.1)},
#  {'text': " I took courses on literature and philosophy that weren't at all required for my computer science and electrical engineering degrees, like a course on James Joyce.",
#   'timestamp': (3619.8, 3628.24)},
#  {'text': ' I played guitar in bars around town.',
#   'timestamp': (3628.7, 3631.9)},
#  {'text': ' I took a lot of technical classes, many, for example, on theoretical computer science, that were way more than were needed for the degree.',
#   'timestamp': (3631.9, 3640.26)},
#  {'text': " I did a lot of research, and I coded up a bunch of projects that didn't directly contribute to my dissertation.",
#   'timestamp': (3640.9, 3647.82)},
#  {'text': ' It was pure curiosity and the joy of exploring.',
#   'timestamp': (3648.96, 3652.7200000000003)},
#  {'text': ' So, like you, I took the long way home, as they say, and I regret none of it.',
#   'timestamp': (3653.6800000000003, 3659.88)},
#  {'text': ' And throughout that, people around me and even people who love me wanted me to hurry up and to focus, especially because I had very little money. And so I had a sense like time was running out for me to take the needed steps towards a reasonable career.',
#   'timestamp': (3659.88, 3677.52)},
#  {'text': ' And just like you, I was filled with anxiety.',
#   'timestamp': (3678.44, 3680.06)},
#  {'text': ' And I still am filled with anxiety to this day.',
#   'timestamp': (3680.86, 3684.0)},
#  {'text': ' But I think the right thing to do is not to run away from the anxiety,',
#   'timestamp': (3684.42, 3688.1)},
#  {'text': ' but to lean into it and channel it into pursuing with everything you got,',
#   'timestamp': (3688.32, 3692.94)},
#  {'text': " the things you're passionate about.",
#   'timestamp': (3693.7, 3695.02)},
#  {'text': " As you said, very importantly, in your heart, you know you're a scientist.",
#   'timestamp': (3695.7, 3699.88)},
#  {'text': " So that's it.", 'timestamp': (3700.36, 3701.2)},
#  {'text': ' You know exactly what to do.', 'timestamp': (3701.5, 3702.72)},
#  {'text': ' Pursue the desire to be a scientist with everything you got.',
#   'timestamp': (3703.36, 3705.88)},
#  {'text': ' get to a good grad school, find a good advisor, and do epic shit with them.',
#   'timestamp': (3705.88, 3712.52)},
#  {'text': ' And it may turn out in the end that your life will have unexpected chapters,',
#   'timestamp': (3713.2200000000003, 3716.86)},
#  {'text': " but as long as you're chasing dreams and goals with absolute, unwavering dedication,",
#   'timestamp': (3717.26, 3722.28)},
#  {'text': ' good stuff will come of it.',
#   'timestamp': (3722.88, 3724.1600000000003)},
#  {'text': ' And also, try your best to be a good person.',
#   'timestamp': (3724.82, 3727.34)},
#  {'text': ' This might be a good place to read the words,',
#   'timestamp': (3728.3, 3731.28)},
#  {'text': " If by Roger Kipling that I often return to when I feel lost and I'm looking for guidance on how to",
#   'timestamp': (3731.28, 3738.0400000000004)},
#  {'text': ' be a better man. If you can keep your head when all about you are losing theirs and blaming it',
#   'timestamp': (3738.0400000000004, 3744.7200000000003)},
#  {'text': ' on you. If you can trust yourself when all men doubt you but make allowance for their doubting',
#   'timestamp': (3744.7200000000003, 3749.94)},
#  {'text': " too. If you can wait and not be tired by waiting or being lied about don't deal in lies or being",
#   'timestamp': (3749.94, 3756.6800000000003)},
#  {'text': " hated don't give way to hating and yet don't look too good nor talk too wise. If you can dream and",
#   'timestamp': (3756.6800000000003, 3764.1800000000003)},
#  {'text': ' not make dreams your master, if you can think and not make thoughts your aim, if you can meet with',
#   'timestamp': (3764.1800000000003, 3769.84)},
#  {'text': ' triumph and disaster and treat those two imposters just the same, if you can bear to hear the truth',
#   'timestamp': (3769.84, 3776.2000000000003)},
#  {'text': " you've spoken, twisted by knaves to make a trap for fools, or watch the things you gave your life",
#   'timestamp': (3776.2000000000003, 3783.2200000000003)},
#  {'text': ' too broken and stoop and build them up with worn out tools. If you can make one heap of all your',
#   'timestamp': (3783.2200000000003, 3790.5600000000004)},
#  {'text': ' winnings and risk it on one turn of pitch and toss and lose and start again at your beginnings',
#   'timestamp': (3790.5600000000004, 3798.38)},
#  {'text': ' and never breathe a word about your loss. If you can force your heart and nerve and sinew',
#   'timestamp': (3798.38, 3805.0200000000004)},
#  {'text': " to serve your turn long after they're gone and so hold on when there's nothing in you",
#   'timestamp': (3805.0200000000004, 3812.32)},
#  {'text': ' except the will which says to them, hold on.',
#   'timestamp': (3812.32, 3815.6000000000004)},
#  {'text': ' If you can talk with crowds and keep your virtue,',
#   'timestamp': (3816.42, 3819.0)},
#  {'text': ' or walk with kings, nor lose the common touch,',
#   'timestamp': (3819.5, 3822.1000000000004)},
#  {'text': ' if neither foes nor loving friends can hurt you,',
#   'timestamp': (3822.6800000000003, 3825.82)},
#  {'text': ' if all men count with you, but none too much.',
#   'timestamp': (3826.38, 3829.8)},
#  {'text': ' If you can fill the unforgiving minute',
#   'timestamp': (3830.82, 3833.46)},
#  {'text': ' with sixty seconds worth of distance run,',
#   'timestamp': (3833.46, 3836.32)},
#  {'text': " yours is the earth and everything that's in it,",
#   'timestamp': (3836.9, 3839.94)},
#  {'text': " And which is more, you'll be a man, my son.",
#   'timestamp': (3839.94, 3843.48)},
#  {'text': ' Thank you for listening.', 'timestamp': (3845.08, 3846.18)},
#  {'text': ' And see you next time.',
#   'timestamp': (3846.7200000000003, 3848.2200000000003)}]
